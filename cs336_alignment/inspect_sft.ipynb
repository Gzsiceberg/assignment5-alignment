# %%
from datasets import load_dataset
ds = load_dataset("../data/sft")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
train = ds["train"]
print(len(train))
# Out:
# 210348

# %%
import random
idx = random.randint(0, len(train) - 1)
example = train[idx]
prompt = example["prompt"]
response = example["response"]
print(prompt)
print("-" * 80)
print(response)
# Out:
# Can you describe the band's early struggles in getting their music heard and how they overcame them?
# --------------------------------------------------------------------------------
# I do not have any particular band in mind to describe their early struggles. However, in general, many bands face the following struggles in getting their music heard:
#
# 1. Lack of exposure: often, new bands struggle to find platforms to showcase their music. Without a strong fan base or connections, it can be challenging to gain exposure.
#
# 2. Financial constraints: recording, producing, and marketing music require a significant amount of money. Many amateur bands lack the budget to produce quality music or hire lawyers to protect their work legally.
#
# ...
